# %%
import time
films = [['Р’РµСЃС‘Р»РѕРµ', ['Р›РѕРєР°Р»СЊРЅРѕР№', ['РЇ, Р­СЂР» Рё СѓРјРёСЂР°СЋС‰Р°СЏ РґРµРІСѓС€РєР°']],  # РљР°С‚Р°Р»РѕРі С„РёР»СЊРјРѕРІ
          ['Р‘РѕР»СЊС€РѕР№', ['Р¤СЂР°РЅС†СѓР·СЃРєРёР№ РІРµСЃС‚РЅРёРє', 'Р‘РµСЃСЃР»Р°РІРЅС‹Рµ СѓР±Р»СЋРґРєРё',
                       'РћРґРЅР°Р¶РґС‹ РІ РіРѕР»Р»РёРІСѓРґРµ', 'Get out']]],
         ['Р—Р°РґСѓРјС‡РёРІРѕРµ', ['Р›РѕРєР°Р»СЊРЅРѕР№', ['РќСЏРЅСЏ', 'РћРґРµСЂР¶РёРјРѕСЃС‚СЊ']],
          ['Р‘РѕР»СЊС€РѕР№', ['CРѕР»РЅС†РµСЃС‚РѕСЏРЅРёРµ', 'РњР°СЏРє',
                       'РњРѕР»С‡Р°РЅРёРµ СЏРіРЅСЏС‚', 'РџСЂРµСЃС‚РёР¶',
                       'РёСЃС‡РµР·РЅСѓРІС€Р°СЏ', 'РЎРёСЏРЅРёРµ']]],
         ['Р›СЋР±РѕРїС‹С‚РЅРѕРµ', ['Р›РѕРєР°Р»СЊРЅРѕР№', ['Р РѕР¶РґРµРЅРёРµ РЅР°С†РёРё', 'РЎС‚Р°РЅС†РёСЏ Р¤СЂСѓС‚РІРµР№Р»']],
          ['Р‘РѕР»СЊС€РѕР№', ['Р§РµР»РѕРІРµРє РїРѕ РёРјРµРЅРё РЎРєРѕС‚С‚', 'Yang Lean: РІ РјРѕРµР№ РіРѕР»РѕРІРµ']]],
         ['Р“СЂСѓСЃС‚РЅРѕРµ', ['Р›РѕРєР°Р»СЊРЅРѕР№', ['РЎРћР”Рђ: Р РµР±РµРЅРѕРє РіР»СѓС…РёС… СЂРѕРґРёС‚РµР»РµР№',
                                     'РќРµРїСЂР°РІРёР»СЊРЅРѕРµ РІРѕСЃРїРёС‚Р°РЅРёРµ РљР°РјРµСЂРѕРЅ РџРѕСЃС‚']],
          ['Р‘РѕР»СЊС€РѕР№', ['РђРјРµСЂРёРєР°РЅСЃРєР°СЏ РёСЃС‚РѕСЂРёСЏ X', 'Р РµРєРІРёРµРј РїРѕ РјРµС‡С‚Рµ', 'РљСЂР°СЃРѕС‚Р° РїРѕ-Р°РјРµСЂРёРєР°РЅСЃРєРё']]]]

# %%
print("РџСЂРёРІРµС‚! Р­С‚Рѕ С‡Р°С‚-Р±РѕС‚, РєРѕС‚РѕСЂС‹Р№ РїРѕР¶РµС‚ С‚РµР±Рµ РІС‹Р±СЂР°С‚СЊ, С‡С‚Рѕ РїРѕСЃРјРѕС‚СЂРµС‚СЊ РІРµС‡РµСЂРѕРј")
print("Р’ РїРµСЂРІСѓСЋ РѕС‡РµСЂРµРґСЊ РґР°РІР°Р№ РїРѕР·РЅР°РєРѕРјРёРјСЃСЏ :)")
print("РљР°Рє С‚РµР±СЏ Р·РѕРІСѓС‚?")
name = input()
a = ""
while a == "":
    ans_1 = ""
    print("РќСѓ С‡С‚Рѕ Р¶, РїСЂРёСЃС‚СѓРїРёРј, ", name, "?")
    while ans_1 != "РґР°":
        if ans_1 == "РЅРµС‚":
            print("Р•СЃР»Рё РїРµСЂРµРґСѓРјР°РµС€СЊ, СЏ С‚РµР±СЏ Р¶РґСѓ С‚СѓС‚, РјРѕР¶РµС€СЊ Р·Р°РєСЂС‹РІР°С‚СЊ РїСЂРѕРіСЂР°РјРјСѓ)")
        else:
            if ans_1 != "":
                print("Р’РІРµРґРёС‚Рµ, РїРѕР¶Р°Р»СѓР№СЃС‚Р°, 'РґР°' РёР»Рё 'РЅРµС‚'. РЇ РЅРµ РїРѕРЅРёРјР°СЋ :(")
        ans_1 = input("(РґР°/РЅРµС‚) ")
    print("Р§РµРј С‚С‹ С…РѕС‡РµС€СЊ СЃРєСЂР°СЃРёС‚СЊ СЃРµРіРѕРґРЅСЏС€РЅРёР№ РІРµС‡РµСЂ?")
    ans_film_or_ser = ""
    while ans_film_or_ser != "С„РёР»СЊРј" and ans_film_or_ser != "СЃРµСЂРёР°Р»":
        ans_film_or_ser = input("(С„РёР»СЊРј/СЃРµСЂРёР°Р») ")
        if not(ans_film_or_ser == "С„РёР»СЊРј" or ans_film_or_ser == "СЃРµСЂРёР°Р»"):
            print("Р’РІРµРґРёС‚Рµ, РїРѕР¶Р°Р»СѓР№СЃС‚Р°, 'С„РёР»СЊРј' РёР»Рё 'СЃРµСЂРёР°Р»'. РЇ РЅРµ РїРѕРЅРёРјР°СЋ :(")
    if ans_film_or_ser == "СЃРµСЂРёР°Р»":
        print("РџСЂРµРґРІРёР¶Сѓ РЅРµРєРѕС‚РѕСЂС‹Рµ СЃР»РѕР¶РЅРѕСЃС‚Рё...")
        print("Р’С‹ Р¶РёРІС‘С‚Рµ РІ Р РѕСЃСЃРёРё?")
        ans_2 = input("(РґР°/РЅРµС‚) ")
        while ans_2 != "РґР°" and ans_2 != "РЅРµС‚":
            print("Р’РІРµРґРёС‚Рµ, РїРѕР¶Р°Р»СѓР№СЃС‚Р°, 'РґР°' РёР»Рё 'РЅРµС‚'. РЇ РЅРµ РїРѕРЅРёРјР°СЋ :(")
            ans_2 = input("(РґР°/РЅРµС‚) ")
        if ans_2 == "РґР°":
            print("РќСѓ С‚РѕРіРґР°, РІ РЅС‹РЅРµС€РЅРµРµ РІСЂРµРјСЏ, РјРѕРіСѓ РїСЂРµРґР»РѕР¶РёС‚СЊ РІР°Рј,",
                  name, ", С‚РѕР»СЊРєРѕ РєРёРЅРѕРїРѕРёСЃРє))))) \n РќРµ СЂР°СЃСЃС‚СЂР°РёРІР°Р№СЃСЏ, СЌС‚Рѕ РѕС‚Р»РёС‡РЅР°СЏ РїР»Р°С‚С„РѕСЂРјР°" 
                        "РґР»СЏ РїРѕРёСЃРєР° СЃРµСЂРёР°Р»РѕРІ")
            print("Р’РѕС‚ СЃСЃС‹Р»РѕС‡РєР°: www.kinopoisk.ru")
        else:
            print("Enjoy watching NETFLIX")
        print("РўСѓС‚ СЏ РїРµСЂРµРєР»Р°РґС‹РІР°СЋ РѕС‚РІРµС‚СЃРІРµРЅРЅРѕСЃС‚СЊ РІС‹Р±РѕСЂР° РЅР° С‚РµР±СЏ Рё РЅР° Р°Р»РіРѕСЂРёС‚РјС‹ СЃР°Р№С‚РѕРІ :)")
        print("РўРµР±СЏ РІ Р»СЋР±РѕРј СЃР»СѓС‡Р°Рµ Р¶РґС‘С‚ Р±РµСЃСЃРѕРЅРЅР°СЏ РЅРѕС‡СЊ!")
    else:
        print("РћС‚Р»РёС‡РЅС‹Р№ РІС‹Р±РѕСЂ! РЇ С‚РѕР¶Рµ Р»СЋР±Р»СЋ Р±РѕР»СЊС€Рµ С„РёР»СЊРјС‹)")
        print("РљР°РєРѕРµ Сѓ С‚РµР±СЏ СЃРµРіРѕРґРЅСЏ РЅР°СЃС‚СЂРѕРµРЅРёРµ?")
        mood = ""
        while mood != "РІРµСЃС‘Р»РѕРµ" and mood != "РіСЂСѓСЃС‚РЅРѕРµ" and\
                mood != "Р»СЋР±РѕРїС‹С‚РЅРѕРµ" and mood != "Р·Р°РґСѓРјС‡РёРІРѕРµ":
            if not(mood == "РІРµСЃС‘Р»РѕРµ" or mood == "РіСЂСѓСЃС‚РЅРѕРµ" or
                   mood == "Р»СЋР±РѕРїС‹С‚РЅРѕРµ" or mood == "Р·Р°РґСѓРјС‡РёРІРѕРµ") \
                    and mood != "":
                print("РќРµРєРѕСЂСЂРµРєС‚РЅС‹Р№ РІРІРѕРґ. РџРѕРїСЂРѕР±СѓР№С‚Рµ РµС‰С‘ СЂР°Р·)")
            mood = input("(РІРµСЃС‘Р»РѕРµ/РіСЂСѓСЃС‚РЅРѕРµ/Р»СЋР±РѕРїС‹С‚РЅРѕРµ/Р·Р°РґСѓРјС‡РёРІРѕРµ)")
        if mood == "РіСЂСѓСЃС‚РЅРѕРµ":
            print("РќРµ РіСЂСѓСЃС‚РёС‚Рµ, ", name, "!!!")
        print(name, ", РїР»Р°РЅРёСЂСѓРµС‚Рµ РїРѕСЃРјРѕС‚СЂРµС‚СЊ С„РёР»СЊРј РѕРґРёРЅ РёР»Рё РІ РєРѕРјРїР°РЅРёРё?")
        alone = input("(РѕРґРёРЅ/РєРѕРјРїР°РЅРёСЏ) ")
        while alone != "РѕРґРёРЅ" and alone != "РєРѕРјРїР°РЅРёСЏ":
            print("РџРѕРІС‚РѕСЂРёС‚Рµ РІРІРѕРґ! РЇ РЅРµ РїРѕРЅСЏР»((")
            alone = input("(РѕРґРёРЅ/РєРѕРјРїР°РЅРёСЏ) ")
        print("РЎРєРѕР»СЊРєРѕ Сѓ РІР°СЃ РІСЂРµРјРµРЅРё РЅР° РїСЂРѕСЃРјРѕС‚СЂ С„РёР»СЊРјР°, ", name, "?")
        time_1_ = input("(С‡РёСЃР»Рѕ, РєРѕР»РёС‡РµСЃС‚РІРѕ РјРёРЅСѓС‚) ")
        flag = 0  # Р¤Р»Р°Рі, РѕСЃС‚Р°РЅРµС‚СЃСЏ 1, РєРѕРіРґР° Р±СѓРґРµС‚ РІРІРµРґРµРЅРѕ С‡РёСЃР»Рѕ
        while flag != 1:  # РџСЂРѕРІРµСЂРєР° РЅР° С‡РёСЃР»Рѕ
            flag = 1
            try:  # РџРѕРїС‹С‚РєР° РїСЂРµРѕР±СЂР°Р·РѕРІР°С‚СЊ РІРІРµРґС‘РЅРЅС‹Рµ РґР°РЅРЅС‹Рµ РІ С‡РёСЃР»Рѕ
                time_1 = int(time_1_)
            except ValueError:  # РќРµСѓРґР°С‡РЅР°СЏ РїРѕРїС‹С‚РєР° РїСЂРµРѕР±СЂР°Р·РѕРІР°С‚СЊ РІРІРµРґС‘РЅРЅС‹Рµ РґР°РЅРЅС‹Рµ РІ СЃС‚СЂРѕРєСѓ
                print("РЇ РІР°СЃ РЅРµ РїРѕРЅСЏР»", name, "(, РІРІРµРґРёС‚Рµ РїРѕР¶Р°Р»СѓР№СЃС‚Р° РёРјРµРЅРЅРѕ С‡РёСЃР»Рѕ")
                time_1_ = input("(С‡РёСЃР»Рѕ, РєРѕР»РёС‡РµСЃС‚РІРѕ РјРёРЅСѓС‚) ")
                flag = 0
        if time_1 < 180:
            t = False
        else:
            t = True
        print("РџСЂРµРґРїРѕС‡С‚РµС€СЊ С„РёР»СЊРј РѕС‚ Р±РѕР»СЊС€РѕР№ СЃС‚СѓРґРёРё?")
        ans_4 = input("(РґР°/РЅРµС‚) ")
        while ans_4 != "РґР°" and ans_4 != "РЅРµС‚":
            print("Р’РІРµРґРёС‚Рµ, РїРѕР¶Р°Р»СѓР№СЃС‚Р°, 'РґР°' РёР»Рё 'РЅРµС‚'. РЇ РЅРµ РїРѕРЅРёРјР°СЋ :(")
            ans_4 = input("(РґР°/РЅРµС‚) ")
        if ans_4 == 'РґР°':
            studio = True
        else:
            studio = False
        if alone == "РѕРґРёРЅ":
            str_1 = "РѕРґРёРЅРѕС‡РµСЃС‚РІРµ"
        else:
            str_1 = "РєРѕРјРїР°РЅРёРё"
        if studio:
            str_2 = "Р‘РѕР»СЊС€РѕР№ СЃС‚СѓРґРёРё"
            f_stud = 1
        else:
            str_2 = "РјР°Р»РѕРёР·РІРµСЃС‚РЅРѕРіРѕ СЂРµР¶РёСЃСЃС‘СЂР°"
            f_stud = 0
        if mood == 'РІРµСЃС‘Р»РѕРµ':
            f_mood = 0
        elif mood == 'Р·Р°РґСѓРјС‡РёРІРѕРµ':
            f_mood = 1
        elif mood == 'Р»СЋР±РѕРїС‹С‚РЅРѕРµ':
            f_mood = 2
        else:
            f_mood = 3
        print("РўР°Рє, С‚Р°Рє, С‚Р°Рє...Р’С‹ С…РѕС‚РёС‚Рµ С‡С‚Рѕ-С‚Рѕ ", mood, ", РґР»СЏ РїСЂРѕСЃРјРѕС‚СЂР° РІ ",
              str_1, " РѕС‚ ", str_2, " Рё РїСЂРёРјРµСЂРЅРѕ РЅР° ", time_1, " РјРёРЅСѓС‚)")
        print('РљР°Р¶РµС‚СЃСЏ СЏ РЅР°С€С‘Р», С‡С‚Рѕ РІС‹ РјРѕР¶РµС‚Рµ СЃРµРіРѕРґРЅСЏ РїРѕСЃРјРѕС‚СЂРµС‚СЊ')
        print('Р­С‚Рѕ Р±СѓРґРµС‚:')
        print(films[f_mood][f_stud+1][1][0], ' (', films[f_mood][0], 'РєРёРЅРѕ РѕС‚ ',
              films[f_mood][f_stud+1][0], 'СЃС‚СѓРґРёРё)')
        # films[f_mood][f_stud+1][1][0] - РѕР±СЂР°С‰Р°РµРјСЃСЏ Рє РѕРїСЂРµРґРµР»С‘РЅРЅРѕРјСѓ С„РёР»СЊРјСѓ РїРѕ РІРІРµРґС‘РЅРЅС‹Рј РґР°РЅРЅС‹Рј
        # films[f_mood][0] - РѕР±СЂР°С‰Р°РµРјСЃСЏ Рє РЅР°СЃС‚СЂРѕРµРЅРёСЋ С„РёР»СЊРјР°
        # films[f_mood][f_stud+1][0] - РѕР±СЂР°С‰Р°РµРјСЃСЏ Рє СЂР°Р·РјРµСЂСѓ СЃС‚СѓРґРёРё
        print(name, "Р’С‹ СѓР¶Рµ СЃРјРѕС‚СЂРµР»Рё СЌС‚РѕС‚ С„РёР»СЊРј?")
        ans_5 = input("(РґР°/РЅРµС‚) ")
        while ans_5 != "РґР°" and ans_5 != "РЅРµС‚":
            print("Р’РІРµРґРёС‚Рµ, РїРѕР¶Р°Р»СѓР№СЃС‚Р°, 'РґР°' РёР»Рё 'РЅРµС‚'. РЇ РЅРµ РїРѕРЅРёРјР°СЋ :(")
            ans_5 = input("(РґР°/РЅРµС‚) ")
        if ans_5 != "РґР°":
            print(name, ", РїСЂРёСЏС‚РЅРѕРіРѕ РїСЂРѕСЃРјРѕС‚СЂР°! Р Р°Рґ, С‡С‚Рѕ СЃРјРѕРі С‚РµР±Рµ РїРѕРјРѕС‡СЊ)")
        else:
            if len(films[f_mood][f_stud+1][1]) != 1:  # РџСЂРѕРІРµСЂСЏРµРј, РµСЃС‚СЊ Р»Рё РµС‰С‘ С„РёР»СЊРјС‹ РїРѕ РґР°РЅРЅРѕРјСѓ Р·Р°РїСЂРѕСЃСѓ
                print('РўРѕРіРґР° РµС‰С‘ РјРѕР¶РµС‚Рµ РїРѕРїСЂРѕР±РѕРІР°С‚СЊ РІС‹Р±СЂР°С‚СЊ РёР· СЌС‚РёС… С„РёР»СЊРјРѕРІ:')
                for i in films[f_mood][f_stud+1][1]:  # Р¦РёРєР» for РїРѕ СЃРїРёСЃРєСѓ
                    if i != films[f_mood][f_stud+1][1][0]:  # РёСЃРєР»СЋС‡Р°РµРј РїРµСЂРІС‹Р№ РїСЂРµРґР»РѕР¶РµРЅРЅС‹Р№ С„РёР»СЊРј
                        print(i)
            else:  # Р•СЃР»Рё Р±С‹Р» РїСЂРµРґР»РѕР¶РµРЅ РµРґРёРЅСЃС‚РµРЅРЅС‹Р№ С„РёР»СЊРј
                print(name, ", РїРµСЂРµСЃРјРѕС‚СЂРё! Р­С‚Рѕ С‚РѕРіРѕ СЃС‚РѕРёС‚!")
        print("Р–РґСѓ, РїРѕРєР° РІС‹ РґРѕСЃРјРѕС‚СЂРёС‚Рµ...")
        # time.sleep(time_1*60)  # РћС‚С‡С‘С‚ РІСЂРµРјРµРЅРё РґРѕ РєРѕРЅС†Р° С„РёР»СЊРјР°
        print("Р’С‹ СѓР¶Рµ РґРѕСЃРјРѕС‚СЂРµР»Рё С„РёР»СЊРј?")
        ans_6 = input("(РґР°/РЅРµС‚) ")
        while ans_6 != "РґР°" and ans_6 != "РЅРµС‚":
            print("Р’РІРµРґРёС‚Рµ, РїРѕР¶Р°Р»СѓР№СЃС‚Р°, 'РґР°' РёР»Рё 'РЅРµС‚'. РЇ РЅРµ РїРѕРЅРёРјР°СЋ :(")
            ans_6 = input("(РґР°/РЅРµС‚) ")
        if ans_6 == "РЅРµС‚":
            print("Рё С‡РµРіРѕ С‚С‹ РѕС‚РІР»РµРєР°РµС€СЊСЃСЏ?")
        else:
            print("Рё РєР°Рє РѕРЅ С‚РµР±Рµ? РћС†РµРЅРё РѕС‚ 0 РґРѕ 10:")
            ball_ = input()
            flag_b = 0  # Р¤Р»Р°Рі, РѕСЃС‚Р°РЅРµС‚СЃСЏ 1, РєРѕРіРґР° Р±СѓРґРµС‚ РІРІРµРґРµРЅРѕ С‡РёСЃР»Рѕ
            while flag_b != 1:  # РџСЂРѕРІРµСЂРєР° РЅР° С‡РёСЃР»Рѕ
                flag_b = 1
                try:  # РџРѕРїС‹С‚РєР° РїСЂРµРѕР±СЂР°Р·РѕРІР°С‚СЊ РІРІРµРґС‘РЅРЅС‹Рµ РґР°РЅРЅС‹Рµ РІ С‡РёСЃР»Рѕ
                    ball = int(ball_)
                except ValueError:  # РќРµСѓРґР°С‡РЅР°СЏ РїРѕРїС‹С‚РєР° РїСЂРµРѕР±СЂР°Р·РѕРІР°С‚СЊ РІРІРµРґС‘РЅРЅС‹Рµ РґР°РЅРЅС‹Рµ РІ СЃС‚СЂРѕРєСѓ
                    print("РЇ РІР°СЃ РЅРµ РїРѕРЅСЏР»", name, "(, РІРІРµРґРёС‚Рµ РїРѕР¶Р°Р»СѓР№СЃС‚Р° РёРјРµРЅРЅРѕ С‡РёСЃР»Рѕ")
                    ball_ = input("(С‡РёСЃР»Рѕ) ")
                    flag_b = 0
            if ball >= 7:
                print("РљР°Р№С„! РћР±СЂР°С‰Р°Р№СЃСЏ СЃРЅРѕРІР°, ", name, "!")
                a = 'da'
            else:
                print("РћС‡РµРЅСЊ Р¶Р°Р»СЊ, РґР°РІР°Р№ РїРѕРїСЂРѕР±СѓРµРј РµС‰С‘ СЂР°Р·!)")
                print("Р•СЃР»Рё РЅРµ С…РѕС‡РµС€СЊ, РїСЂРѕСЃС‚Рѕ РѕСЃС‚Р°РЅРѕРІРё РїСЂРѕРіСЂР°РјРјСѓ)")
                print("РёР»Рё СЏ РїРµСЂРµР·Р°РїСѓС‰СѓСЃСЊ Р§Р•Р Р•Р—")
                for i in range(10, 0, -1):
                    print(i, "СЃРµРєСѓРЅРґ")
                    time.sleep(1)
print('Р”Рѕ СЃРІРёРґР°РЅРёСЏ!')
